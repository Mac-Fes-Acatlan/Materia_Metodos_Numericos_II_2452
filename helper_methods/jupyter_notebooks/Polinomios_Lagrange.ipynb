# %%
import numpy as np
import sympy as sym
import matplotlib.pyplot as plt


xi = np.array([2, 3, 6, 7,8])
fi = np.array([92.13, 94.9, 93.75, 93.55,93.92])

# %%
n = len(xi)
x = sym.Symbol('x')
polinomio = 0
divisorL = np.zeros(n, dtype = float)

# %%
for i in range(0,n,1):
    
    numerador = 1
    denominador = 1
    for j  in range(0,n,1):
        if (j!=i):
            numerador = numerador*(x-xi[j])
            denominador = denominador*(xi[i]-xi[j])
    terminoLi = numerador/denominador

    polinomio = polinomio + terminoLi*fi[i]
    divisorL[i] = denominador

# %%
polinomio
# Out:
# 0.76775*(x - 8)*(x - 7)*(x - 6)*(x - 3) - 1.58166666666667*(x - 8)*(x - 7)*(x - 6)*(x - 2) + 3.90625*(x - 8)*(x - 7)*(x - 3)*(x - 2) - 4.6775*(x - 8)*(x - 6)*(x - 3)*(x - 2) + 1.56533333333333*(x - 7)*(x - 6)*(x - 3)*(x - 2)

# %%
# simplifica el polinomio
polisimple = polinomio.expand()

# para evaluación numérica
px = sym.lambdify(x,polisimple)

# Puntos para la gráfica
muestras = 101
a = np.min(xi)
b = np.max(xi)
pxi = np.linspace(a,b,muestras)
pfi = px(pxi)

# SALIDA
print('    valores de fi: ',fi)
print('divisores en L(i): ',divisorL)
print()
print('Polinomio de Lagrange, expresiones')
print(polinomio)
print()
print('Polinomio de Lagrange: ')
print(polisimple)

# Gráfica
plt.plot(xi,fi,'o', label = 'Puntos')
plt.plot(pxi,pfi, label = 'Polinomio')
plt.legend()
plt.xlabel('xi')
plt.ylabel('fi')
plt.title('Interpolación Lagrange')
plt.show()
# Out:
#     valores de fi:  [92.13 94.9  93.75 93.55 93.92]
# divisores en L(i):  [120. -60.  24. -20.  60.]
#
# Polinomio de Lagrange, expresiones
# 0.76775*(x - 8)*(x - 7)*(x - 6)*(x - 3) - 1.58166666666667*(x - 8)*(x - 7)*(x - 6)*(x - 2) + 3.90625*(x - 8)*(x - 7)*(x - 3)*(x - 2) - 4.6775*(x - 8)*(x - 6)*(x - 3)*(x - 2) + 1.56533333333333*(x - 7)*(x - 6)*(x - 3)*(x - 2)
#
# Polinomio de Lagrange:
# -0.0198333333333343*x**4 + 0.523833333333336*x**3 - 4.86466666666672*x**2 + 18.4296666666665*x + 70.8559999999995
